# %%
print("welcome to the Treasure Island, your mission is to find the treasure")
choice1=input('you are at cross road where you want to go "left" or "right"').lower()
if choice1== "left":
    choice2=(input('you come to a lake. there is an island in the middle of the lake. type "wait" to wait for a boat, type "swim" to swim cross')).lower()
    if choice2== "wait" :
        choice3=input('you are reached at a door,which door you will choose "red","blue","yellow"').lower()
        if choice3== "yellow":
            print("you found the treasure!!! you won the game!!!")
        elif choice3== "red":
            print('you have enterd a room full of beast."game over!!!"')
                  
        elif choice3== "blue":
            print('you have enterd a room full of fire. "game over.!!!"')
        
        else:
            print('you chose a door that does not exist. "game over!!!."')
            
    else:
        print('you are attacked by an angry trout. "game over"!!! ')
        
else:
    print('there is hole, and you are already fallen in that hole "game over!!!!"')
# Out:
# welcome to the Treasure Island, your mission is to find the treasure
# you are at cross road where you want to go "left" or "right"left
# you come to a lake. there is an island in the middle of the lake. type "wait" to wait for a boat, type "swim" to swim crosswait
# you are reached at a door,which door you will choose "red","blue","yellow"blue
# you have enterd a room full of fire. "game over.!!!"
